# %%
import numpy as np 
import matplotlib.pyplot as plt
import random
from sklearn.linear_model import LinearRegression

# %% [markdown]
# We simulate the following additive noise model
# $$
# Y = 0.5 \cdot X + N_Y,
# $$
# with uniformly distributed and independent cause $X$ and noise $N_Y$.

# %%
a = 0 
b = 1 
n =  10**3

random.seed(7)
X = np.random.uniform(low = a , high = b , size = n)
N_Y =  np.random.uniform(low = a , high = b , size = n)
Y = 0.5 * X + N_Y

causal_model = LinearRegression()
causal_model.fit(X.reshape(-1 , 1) , Y )
Y_hat = causal_model.predict(X.reshape(-1 , 1))
residual_causal = Y_hat - Y 

plt.scatter(X, residual_causal)

# Add labels
plt.xlabel("X")
plt.ylabel("Residual of regre. Y on X")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 25
#      19 plt.ylabel("Residual of regre. Y on X")
#      22 ###### Hilbert--Schmidt Independence Criterion
# ---> 25 hsic_test = Hsic()
#      26 stat, pvalue = hsic_test.test(X, residual_causal)
#      28 print("HSIC statistic:", stat)
#
# NameError: name 'Hsic' is not defined

# %%
###### Hilbert--Schmidt Independence Criterion
from hyppo.independence import Hsic

hsic_test = Hsic()
stat, pvalue = hsic_test.test(X, residual_causal)

print("HSIC statistic:", stat)
print("p-value:", pvalue)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[48], line 2
#       1 ###### Hilbert--Schmidt Independence Criterion
# ----> 2 from hyppo.independence import Hsic
#       4 hsic_test = Hsic()
#       5 stat, pvalue = hsic_test.test(X, residual_causal)
#
# ModuleNotFoundError: No module named 'hyppo'

# %%
anticausal_model = LinearRegression()
anticausal_model.fit(Y.reshape(-1 , 1) , X )
X_hat = anticausal_model.predict(Y.reshape(-1 , 1))

residual_anticausal = X_hat - X 

plt.scatter(Y, residual_anticausal)

# Add labels
plt.xlabel("Y")
plt.ylabel("Residual of regre. X on Y")
# Out:
# Text(0, 0.5, 'Residual of regre. X on Y')
